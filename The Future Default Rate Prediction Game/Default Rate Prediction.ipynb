# %% [markdown]
# ### Inicio

# %% [markdown]
# #### Librerías

# %%
print "IMPORTING LIBRARIES..."
import pandas as pd
import numpy as np
import statsmodels.api as sm
import re
import requests
import math
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats
import pickle
import cPickle
# Out:
# IMPORTING LIBRARIES...

# %% [markdown]
# #### Descarga de ficheros

# %%
#DOWLOADING FILE FROM DROPBOX FIRST TIME
import os.path
import time
import random
while not os.path.exists('EX2_DATA_BASE.xlsx'):
    time.sleep (3*random.random()); #Sleeping less than 3 seconds before going to Dropbox - avoid too many students at once.
    if not os.path.exists('EX2_DATA_BASE.xlsx'):
        print "DOWLOADING FILE EX2_DATA_BASE.xlsx FROM DROPBOX BECAUSE LOCAL FILE DOES NOT EXIST!"
#        csvfile = urllib2.urlopen("https://dl.dropboxusercontent.com/u/28535341/EX2_DEV_DATA.xlsx")
        resp = requests.get("https://dl.dropboxusercontent.com/u/28535341/EX2_DATA_BASE.xlsx")        
        output = open('EX2_DATA_BASE.xlsx','wb')
        output.write(resp.content)
        output.close()
#DOWLOADING FILE FROM DROPBOX FIRST TIME

# %% [markdown]
# #### Datasets

# %%
print "LOADING DATASETS..."
#df = pd.read_csv("EX2_DEV_DATA.xlsx",sep=";") #DEV-SAMPLE
df = pd.read_excel(open('EX2_DATA_BASE.xlsx','rb'), sheetname='DATA')
df_dictionary = pd.read_excel(open('EX2_DATA_BASE.xlsx','rb'), sheetname='DICTIONARY')
# Out:
# LOADING DATASETS...

# %% [markdown]
# #### Variables

# %%
print "GETTING LIST OF VARIABLES..."

print "-> target variable:"
target_variable = str(df_dictionary[df_dictionary['TYPE_OF_VARIABLE'] == 'TARGET']['FIELD_NAME'].tolist()[0])
print "target_variable = ",target_variable


list_of_inputs_for_model0 = df_dictionary[df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT0']['FIELD_NAME'].tolist()
list_of_inputs_for_model0.remove('TICKER')
list_of_inputs_for_model0.remove('NAME')
list_of_inputs_for_model0.remove('INDUSTRY_GROUP')
#print "list_of_inputs_for_model0 = ",list_of_inputs_for_model0

list_of_inputs_for_model1 = df_dictionary[(df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT0') | 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT1')]['FIELD_NAME'].tolist()
list_of_inputs_for_model1.remove('TICKER')
list_of_inputs_for_model1.remove('NAME')
list_of_inputs_for_model1.remove('INDUSTRY_GROUP')
#print "list_of_inputs_for_model1 = ",list_of_inputs_for_model1

list_of_inputs_for_model2 = df_dictionary[(df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT0') | 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT1')| 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT2')]['FIELD_NAME'].tolist()
list_of_inputs_for_model2.remove('TICKER')
list_of_inputs_for_model2.remove('NAME')
list_of_inputs_for_model2.remove('INDUSTRY_GROUP')
#print "list_of_inputs_for_model2 = ",list_of_inputs_for_model2

list_of_inputs_for_model3 = df_dictionary[(df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT0') | 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT1')| 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT2')| 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT3')]['FIELD_NAME'].tolist()
list_of_inputs_for_model3.remove('TICKER')
list_of_inputs_for_model3.remove('NAME')
list_of_inputs_for_model3.remove('INDUSTRY_GROUP')
#print "list_of_inputs_for_model3 = ",list_of_inputs_for_model3

list_of_inputs_for_model4 = df_dictionary[(df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT0') | 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT1')| 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT2')| 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT3')| 
                                          (df_dictionary['TYPE_OF_VARIABLE'] == 'INPUT4')]['FIELD_NAME'].tolist()
list_of_inputs_for_model4.remove('TICKER')
list_of_inputs_for_model4.remove('NAME')
list_of_inputs_for_model4.remove('INDUSTRY_GROUP')
#print "list_of_inputs_for_model4 = ",list_of_inputs_for_model4

df = df.fillna(0)
# Out:
# GETTING LIST OF VARIABLES...
# -> target variable:
# target_variable =  BB_1YR_DEFAULT_PROB_CQ4_2015

# %% [markdown]
# ### Trabajo

# %% [markdown]
# #### Transformaciones

# %% [markdown]
# Creamos algunos ratios:

# %%
#### PREDICTING -  target_variable #######

print "STEP 1: DOING MY TRANSFORMATIONS..."

#non_continuous_inputs = ['TICKER', 'NAME', 'INDUSTRY_GROUP']
df['ROE_CQ4_2013'] = df['NET_INCOME_CQ4_2013']/df['TOTAL_EQUITY_CQ4_2013']
df['ROE_CQ4_2014'] = df['NET_INCOME_CQ4_2014']/df['TOTAL_EQUITY_CQ4_2014']
df['ROE_CQ1_2015'] = df['NET_INCOME_CQ1_2015']/df['TOTAL_EQUITY_CQ1_2015']
df['ROE_CQ2_2015'] = df['NET_INCOME_CQ2_2015']/df['TOTAL_EQUITY_CQ2_2015']
df['ROE_CQ3_2015'] = df['NET_INCOME_CQ3_2015']/df['TOTAL_EQUITY_CQ3_2015']
df['ROE_CQ4_2015'] = df['NET_INCOME_CQ4_2015']/df['TOTAL_EQUITY_CQ4_2015']

df['ROA_CQ4_2013'] = df['NET_INCOME_CQ4_2013']/df['BS_TOT_ASSET_CQ4_2013']
df['ROA_CQ4_2014'] = df['NET_INCOME_CQ4_2014']/df['BS_TOT_ASSET_CQ4_2014']
df['ROA_CQ1_2015'] = df['NET_INCOME_CQ1_2015']/df['BS_TOT_ASSET_CQ1_2015']
df['ROA_CQ2_2015'] = df['NET_INCOME_CQ2_2015']/df['BS_TOT_ASSET_CQ2_2015']
df['ROA_CQ3_2015'] = df['NET_INCOME_CQ3_2015']/df['BS_TOT_ASSET_CQ3_2015']
df['ROA_CQ4_2015'] = df['NET_INCOME_CQ4_2015']/df['BS_TOT_ASSET_CQ4_2015']

df['EV_EBITDA_CQ4_2013'] = (df['CUR_MKT_CAP_CQ4_2013']+df['BS_CUR_LIAB_CQ4_2013']+df['NON_CUR_LIAB_CQ4_2013']-df['BS_CASH_NEAR_CASH_ITEM_CQ4_2013'])/df['IS_EBITDA_CQ4_2013']
df['EV_EBITDA_CQ4_2014'] = (df['CUR_MKT_CAP_CQ4_2014']+df['BS_CUR_LIAB_CQ4_2014']+df['NON_CUR_LIAB_CQ4_2014']-df['BS_CASH_NEAR_CASH_ITEM_CQ4_2014'])/df['IS_EBITDA_CQ4_2014']
df['EV_EBITDA_CQ1_2015'] = (df['CUR_MKT_CAP_CQ1_2015']+df['BS_CUR_LIAB_CQ1_2015']+df['NON_CUR_LIAB_CQ1_2015']-df['BS_CASH_NEAR_CASH_ITEM_CQ1_2015'])/df['IS_EBITDA_CQ1_2015']
df['EV_EBITDA_CQ2_2015'] = (df['CUR_MKT_CAP_CQ2_2015']+df['BS_CUR_LIAB_CQ2_2015']+df['NON_CUR_LIAB_CQ2_2015']-df['BS_CASH_NEAR_CASH_ITEM_CQ2_2015'])/df['IS_EBITDA_CQ2_2015']
df['EV_EBITDA_CQ3_2015'] = (df['CUR_MKT_CAP_CQ3_2015']+df['BS_CUR_LIAB_CQ3_2015']+df['NON_CUR_LIAB_CQ3_2015']-df['BS_CASH_NEAR_CASH_ITEM_CQ3_2015'])/df['IS_EBITDA_CQ3_2015']
df['EV_EBITDA_CQ4_2015'] = (df['CUR_MKT_CAP_CQ4_2015']+df['BS_CUR_LIAB_CQ4_2015']+df['NON_CUR_LIAB_CQ4_2015']-df['BS_CASH_NEAR_CASH_ITEM_CQ4_2015'])/df['IS_EBITDA_CQ4_2015']

df['FONDO_MANIOBRA_CQ4_2013'] = df['BS_CUR_ASSET_REPORT_CQ4_2013'] - df['BS_CUR_LIAB_CQ4_2013']
df['FONDO_MANIOBRA_CQ4_2014'] = df['BS_CUR_ASSET_REPORT_CQ4_2014'] - df['BS_CUR_LIAB_CQ4_2014']
df['FONDO_MANIOBRA_CQ1_2015'] = df['BS_CUR_ASSET_REPORT_CQ1_2015'] - df['BS_CUR_LIAB_CQ1_2015']
df['FONDO_MANIOBRA_CQ2_2015'] = df['BS_CUR_ASSET_REPORT_CQ2_2015'] - df['BS_CUR_LIAB_CQ2_2015']
df['FONDO_MANIOBRA_CQ3_2015'] = df['BS_CUR_ASSET_REPORT_CQ3_2015'] - df['BS_CUR_LIAB_CQ3_2015']
df['FONDO_MANIOBRA_CQ4_2015'] = df['BS_CUR_ASSET_REPORT_CQ4_2015'] - df['BS_CUR_LIAB_CQ4_2015']

df['DEUDA_CUR_CQ4_2013'] = df['BS_CUR_LIAB_CQ4_2013']/df['TOTAL_EQUITY_CQ4_2013']
df['DEUDA_CUR_CQ4_2014'] = df['BS_CUR_LIAB_CQ4_2014']/df['TOTAL_EQUITY_CQ4_2014']
df['DEUDA_CUR_CQ1_2015'] = df['BS_CUR_LIAB_CQ1_2015']/df['TOTAL_EQUITY_CQ1_2015']
df['DEUDA_CUR_CQ2_2015'] = df['BS_CUR_LIAB_CQ2_2015']/df['TOTAL_EQUITY_CQ2_2015']
df['DEUDA_CUR_CQ3_2015'] = df['BS_CUR_LIAB_CQ3_2015']/df['TOTAL_EQUITY_CQ3_2015']
df['DEUDA_CUR_CQ4_2015'] = df['BS_CUR_LIAB_CQ4_2015']/df['TOTAL_EQUITY_CQ4_2015']

df['DEUDA_NON_CUR_CQ4_2013'] = df['NON_CUR_LIAB_CQ4_2013']/df['TOTAL_EQUITY_CQ4_2013']
df['DEUDA_NON_CUR_CQ4_2014'] = df['NON_CUR_LIAB_CQ4_2014']/df['TOTAL_EQUITY_CQ4_2014']
df['DEUDA_NON_CUR_CQ1_2015'] = df['NON_CUR_LIAB_CQ1_2015']/df['TOTAL_EQUITY_CQ1_2015']
df['DEUDA_NON_CUR_CQ2_2015'] = df['NON_CUR_LIAB_CQ2_2015']/df['TOTAL_EQUITY_CQ2_2015']
df['DEUDA_NON_CUR_CQ3_2015'] = df['NON_CUR_LIAB_CQ3_2015']/df['TOTAL_EQUITY_CQ3_2015']
df['DEUDA_NON_CUR_CQ4_2015'] = df['NON_CUR_LIAB_CQ4_2015']/df['TOTAL_EQUITY_CQ4_2015']

df['ROTACION_ACTIVOS_CQ4_2013'] = df['SALES_REV_TURN_CQ4_2013']/df['BS_TOT_ASSET_CQ4_2013']
df['ROTACION_ACTIVOS_CQ4_2014'] = df['SALES_REV_TURN_CQ4_2014']/df['BS_TOT_ASSET_CQ4_2014']
df['ROTACION_ACTIVOS_CQ1_2015'] = df['SALES_REV_TURN_CQ1_2015']/df['BS_TOT_ASSET_CQ1_2015']
df['ROTACION_ACTIVOS_CQ2_2015'] = df['SALES_REV_TURN_CQ2_2015']/df['BS_TOT_ASSET_CQ2_2015']
df['ROTACION_ACTIVOS_CQ3_2015'] = df['SALES_REV_TURN_CQ3_2015']/df['BS_TOT_ASSET_CQ3_2015']
df['ROTACION_ACTIVOS_CQ4_2015'] = df['SALES_REV_TURN_CQ4_2015']/df['BS_TOT_ASSET_CQ4_2015']

df['MARGEN_OPERATIVO_CQ4_2013'] = df['IS_OPER_INC_CQ4_2013']/df['BS_TOT_ASSET_CQ4_2013']
df['MARGEN_OPERATIVO_CQ4_2014'] = df['IS_OPER_INC_CQ4_2014']/df['BS_TOT_ASSET_CQ4_2014']
df['MARGEN_OPERATIVO_CQ1_2015'] = df['IS_OPER_INC_CQ1_2015']/df['BS_TOT_ASSET_CQ1_2015']
df['MARGEN_OPERATIVO_CQ2_2015'] = df['IS_OPER_INC_CQ2_2015']/df['BS_TOT_ASSET_CQ2_2015']
df['MARGEN_OPERATIVO_CQ3_2015'] = df['IS_OPER_INC_CQ3_2015']/df['BS_TOT_ASSET_CQ3_2015']
df['MARGEN_OPERATIVO_CQ4_2015'] = df['IS_OPER_INC_CQ4_2015']/df['BS_TOT_ASSET_CQ4_2015']

df['PRODUCTIVIDAD_PERSONAL_CQ4_2013'] = df['IS_OPER_INC_CQ4_2013']/df['IS_PERSONNEL_EXP_CQ4_2013']
df['PRODUCTIVIDAD_PERSONAL_CQ4_2014'] = df['IS_OPER_INC_CQ4_2014']/df['IS_PERSONNEL_EXP_CQ4_2014']
df['PRODUCTIVIDAD_PERSONAL_CQ1_2015'] = df['IS_OPER_INC_CQ1_2015']/df['IS_PERSONNEL_EXP_CQ1_2015']
df['PRODUCTIVIDAD_PERSONAL_CQ2_2015'] = df['IS_OPER_INC_CQ2_2015']/df['IS_PERSONNEL_EXP_CQ2_2015']
df['PRODUCTIVIDAD_PERSONAL_CQ3_2015'] = df['IS_OPER_INC_CQ3_2015']/df['IS_PERSONNEL_EXP_CQ3_2015']
df['PRODUCTIVIDAD_PERSONAL_CQ4_2015'] = df['IS_OPER_INC_CQ4_2015']/df['IS_PERSONNEL_EXP_CQ4_2015']
# Out:
# STEP 1: DOING MY TRANSFORMATIONS...

# %%
# Eliminamos valores NaN y Inf
df = df.replace(-np.inf, 0)
df = df.replace(np.inf, 0)
df = df.fillna(0)

# %%
df.describe()
# Out:
#        TOTAL_EQUITY_CQ4_2013  TOTAL_EQUITY_CQ1_2014  TOTAL_EQUITY_CQ2_2014  \
# count             116.000000             116.000000             116.000000
# mean             3405.747837            3462.535691            3562.119567
# std             10227.498294           10425.211799           10748.810957
# min             -2400.056000           -2469.600000           -2835.559000
# 25%                 0.000000               0.000000               0.000000
# 50%               127.332000             126.509000             162.813000
# 75%              1454.268750            1515.740000            1472.134000
# max             79642.000000           82522.000000           85716.000000
#
#        TOTAL_EQUITY_CQ3_2014  TOTAL_EQUITY_CQ4_2014  TOTAL_EQUITY_CQ1_2015  \
# count             116.000000             116.000000             116.000000
# mean             3648.388109            3606.414533            3836.913675
# ...

# %%
# Añadimos los ratios a los inputs de los modelos:

# ROE
list_of_inputs_for_model0.append('ROE_CQ4_2013')
list_of_inputs_for_model1.append('ROE_CQ4_2013')
list_of_inputs_for_model2.append('ROE_CQ4_2013')
list_of_inputs_for_model3.append('ROE_CQ4_2013')
list_of_inputs_for_model4.append('ROE_CQ4_2013')

list_of_inputs_for_model0.append('ROE_CQ4_2014')
list_of_inputs_for_model1.append('ROE_CQ4_2014')
list_of_inputs_for_model2.append('ROE_CQ4_2014')
list_of_inputs_for_model3.append('ROE_CQ4_2014')
list_of_inputs_for_model4.append('ROE_CQ4_2014')

list_of_inputs_for_model1.append('ROE_CQ1_2015')
list_of_inputs_for_model2.append('ROE_CQ1_2015')
list_of_inputs_for_model3.append('ROE_CQ1_2015')
list_of_inputs_for_model4.append('ROE_CQ1_2015')

list_of_inputs_for_model2.append('ROE_CQ2_2015')
list_of_inputs_for_model3.append('ROE_CQ2_2015')
list_of_inputs_for_model4.append('ROE_CQ2_2015')

list_of_inputs_for_model3.append('ROE_CQ3_2015')
list_of_inputs_for_model4.append('ROE_CQ3_2015')

list_of_inputs_for_model4.append('ROE_CQ4_2015')

# ROA
list_of_inputs_for_model0.append('ROA_CQ4_2013')
list_of_inputs_for_model1.append('ROA_CQ4_2013')
list_of_inputs_for_model2.append('ROA_CQ4_2013')
list_of_inputs_for_model3.append('ROA_CQ4_2013')
list_of_inputs_for_model4.append('ROA_CQ4_2013')

list_of_inputs_for_model0.append('ROA_CQ4_2014')
list_of_inputs_for_model1.append('ROA_CQ4_2014')
list_of_inputs_for_model2.append('ROA_CQ4_2014')
list_of_inputs_for_model3.append('ROA_CQ4_2014')
list_of_inputs_for_model4.append('ROA_CQ4_2014')

list_of_inputs_for_model1.append('ROA_CQ1_2015')
list_of_inputs_for_model2.append('ROA_CQ1_2015')
list_of_inputs_for_model3.append('ROA_CQ1_2015')
list_of_inputs_for_model4.append('ROA_CQ1_2015')

list_of_inputs_for_model2.append('ROA_CQ2_2015')
list_of_inputs_for_model3.append('ROA_CQ2_2015')
list_of_inputs_for_model4.append('ROA_CQ2_2015')

list_of_inputs_for_model3.append('ROA_CQ3_2015')
list_of_inputs_for_model4.append('ROA_CQ3_2015')

list_of_inputs_for_model4.append('ROA_CQ4_2015')

# EV/EBITDA
list_of_inputs_for_model0.append('EV_EBITDA_CQ4_2013')
list_of_inputs_for_model1.append('EV_EBITDA_CQ4_2013')
list_of_inputs_for_model2.append('EV_EBITDA_CQ4_2013')
list_of_inputs_for_model3.append('EV_EBITDA_CQ4_2013')
list_of_inputs_for_model4.append('EV_EBITDA_CQ4_2013')

list_of_inputs_for_model0.append('EV_EBITDA_CQ4_2014')
list_of_inputs_for_model1.append('EV_EBITDA_CQ4_2014')
list_of_inputs_for_model2.append('EV_EBITDA_CQ4_2014')
list_of_inputs_for_model3.append('EV_EBITDA_CQ4_2014')
list_of_inputs_for_model4.append('EV_EBITDA_CQ4_2014')

list_of_inputs_for_model1.append('EV_EBITDA_CQ1_2015')
list_of_inputs_for_model2.append('EV_EBITDA_CQ1_2015')
list_of_inputs_for_model3.append('EV_EBITDA_CQ1_2015')
list_of_inputs_for_model4.append('EV_EBITDA_CQ1_2015')

list_of_inputs_for_model2.append('EV_EBITDA_CQ2_2015')
list_of_inputs_for_model3.append('EV_EBITDA_CQ2_2015')
list_of_inputs_for_model4.append('EV_EBITDA_CQ2_2015')

list_of_inputs_for_model3.append('EV_EBITDA_CQ3_2015')
list_of_inputs_for_model4.append('EV_EBITDA_CQ3_2015')

list_of_inputs_for_model4.append('EV_EBITDA_CQ4_2015')

# FONDO DE MANIOBRA
list_of_inputs_for_model0.append('FONDO_MANIOBRA_CQ4_2013')
list_of_inputs_for_model1.append('FONDO_MANIOBRA_CQ4_2013')
list_of_inputs_for_model2.append('FONDO_MANIOBRA_CQ4_2013')
list_of_inputs_for_model3.append('FONDO_MANIOBRA_CQ4_2013')
list_of_inputs_for_model4.append('FONDO_MANIOBRA_CQ4_2013')

list_of_inputs_for_model0.append('FONDO_MANIOBRA_CQ4_2014')
list_of_inputs_for_model1.append('FONDO_MANIOBRA_CQ4_2014')
list_of_inputs_for_model2.append('FONDO_MANIOBRA_CQ4_2014')
list_of_inputs_for_model3.append('FONDO_MANIOBRA_CQ4_2014')
list_of_inputs_for_model4.append('FONDO_MANIOBRA_CQ4_2014')

list_of_inputs_for_model1.append('FONDO_MANIOBRA_CQ1_2015')
list_of_inputs_for_model2.append('FONDO_MANIOBRA_CQ1_2015')
list_of_inputs_for_model3.append('FONDO_MANIOBRA_CQ1_2015')
list_of_inputs_for_model4.append('FONDO_MANIOBRA_CQ1_2015')

list_of_inputs_for_model2.append('FONDO_MANIOBRA_CQ2_2015')
list_of_inputs_for_model3.append('FONDO_MANIOBRA_CQ2_2015')
list_of_inputs_for_model4.append('FONDO_MANIOBRA_CQ2_2015')

list_of_inputs_for_model3.append('FONDO_MANIOBRA_CQ3_2015')
list_of_inputs_for_model4.append('FONDO_MANIOBRA_CQ3_2015')

list_of_inputs_for_model4.append('FONDO_MANIOBRA_CQ4_2015')

# ENDEUDAMIENTO CORTO PLAZO
list_of_inputs_for_model0.append('DEUDA_CUR_CQ4_2013')
list_of_inputs_for_model1.append('DEUDA_CUR_CQ4_2013')
list_of_inputs_for_model2.append('DEUDA_CUR_CQ4_2013')
list_of_inputs_for_model3.append('DEUDA_CUR_CQ4_2013')
list_of_inputs_for_model4.append('DEUDA_CUR_CQ4_2013')

list_of_inputs_for_model0.append('DEUDA_CUR_CQ4_2014')
list_of_inputs_for_model1.append('DEUDA_CUR_CQ4_2014')
list_of_inputs_for_model2.append('DEUDA_CUR_CQ4_2014')
list_of_inputs_for_model3.append('DEUDA_CUR_CQ4_2014')
list_of_inputs_for_model4.append('DEUDA_CUR_CQ4_2014')

list_of_inputs_for_model1.append('DEUDA_CUR_CQ1_2015')
list_of_inputs_for_model2.append('DEUDA_CUR_CQ1_2015')
list_of_inputs_for_model3.append('DEUDA_CUR_CQ1_2015')
list_of_inputs_for_model4.append('DEUDA_CUR_CQ1_2015')

list_of_inputs_for_model2.append('DEUDA_CUR_CQ2_2015')
list_of_inputs_for_model3.append('DEUDA_CUR_CQ2_2015')
list_of_inputs_for_model4.append('DEUDA_CUR_CQ2_2015')

list_of_inputs_for_model3.append('DEUDA_CUR_CQ3_2015')
list_of_inputs_for_model4.append('DEUDA_CUR_CQ3_2015')

list_of_inputs_for_model4.append('DEUDA_CUR_CQ4_2015')

# ENDEUDAMIENTO LARGO PLAZO
list_of_inputs_for_model0.append('DEUDA_NON_CUR_CQ4_2013')
list_of_inputs_for_model1.append('DEUDA_NON_CUR_CQ4_2013')
list_of_inputs_for_model2.append('DEUDA_NON_CUR_CQ4_2013')
list_of_inputs_for_model3.append('DEUDA_NON_CUR_CQ4_2013')
list_of_inputs_for_model4.append('DEUDA_NON_CUR_CQ4_2013')

list_of_inputs_for_model0.append('DEUDA_NON_CUR_CQ4_2014')
list_of_inputs_for_model1.append('DEUDA_NON_CUR_CQ4_2014')
list_of_inputs_for_model2.append('DEUDA_NON_CUR_CQ4_2014')
list_of_inputs_for_model3.append('DEUDA_NON_CUR_CQ4_2014')
list_of_inputs_for_model4.append('DEUDA_NON_CUR_CQ4_2014')

list_of_inputs_for_model1.append('DEUDA_NON_CUR_CQ1_2015')
list_of_inputs_for_model2.append('DEUDA_NON_CUR_CQ1_2015')
list_of_inputs_for_model3.append('DEUDA_NON_CUR_CQ1_2015')
list_of_inputs_for_model4.append('DEUDA_NON_CUR_CQ1_2015')

list_of_inputs_for_model2.append('DEUDA_NON_CUR_CQ2_2015')
list_of_inputs_for_model3.append('DEUDA_NON_CUR_CQ2_2015')
list_of_inputs_for_model4.append('DEUDA_NON_CUR_CQ2_2015')

list_of_inputs_for_model3.append('DEUDA_NON_CUR_CQ3_2015')
list_of_inputs_for_model4.append('DEUDA_NON_CUR_CQ3_2015')

list_of_inputs_for_model4.append('DEUDA_NON_CUR_CQ4_2015')

# ROTACIÓN DE ACTIVOS
list_of_inputs_for_model0.append('ROTACION_ACTIVOS_CQ4_2013')
list_of_inputs_for_model1.append('ROTACION_ACTIVOS_CQ4_2013')
list_of_inputs_for_model2.append('ROTACION_ACTIVOS_CQ4_2013')
list_of_inputs_for_model3.append('ROTACION_ACTIVOS_CQ4_2013')
list_of_inputs_for_model4.append('ROTACION_ACTIVOS_CQ4_2013')

list_of_inputs_for_model0.append('ROTACION_ACTIVOS_CQ4_2014')
list_of_inputs_for_model1.append('ROTACION_ACTIVOS_CQ4_2014')
list_of_inputs_for_model2.append('ROTACION_ACTIVOS_CQ4_2014')
list_of_inputs_for_model3.append('ROTACION_ACTIVOS_CQ4_2014')
list_of_inputs_for_model4.append('ROTACION_ACTIVOS_CQ4_2014')

list_of_inputs_for_model1.append('ROTACION_ACTIVOS_CQ1_2015')
list_of_inputs_for_model2.append('ROTACION_ACTIVOS_CQ1_2015')
list_of_inputs_for_model3.append('ROTACION_ACTIVOS_CQ1_2015')
list_of_inputs_for_model4.append('ROTACION_ACTIVOS_CQ1_2015')

list_of_inputs_for_model2.append('ROTACION_ACTIVOS_CQ2_2015')
list_of_inputs_for_model3.append('ROTACION_ACTIVOS_CQ2_2015')
list_of_inputs_for_model4.append('ROTACION_ACTIVOS_CQ2_2015')

list_of_inputs_for_model3.append('ROTACION_ACTIVOS_CQ3_2015')
list_of_inputs_for_model4.append('ROTACION_ACTIVOS_CQ3_2015')

list_of_inputs_for_model4.append('ROTACION_ACTIVOS_CQ4_2015')

# MARGEN OPERATIVO
list_of_inputs_for_model0.append('MARGEN_OPERATIVO_CQ4_2013')
list_of_inputs_for_model1.append('MARGEN_OPERATIVO_CQ4_2013')
list_of_inputs_for_model2.append('MARGEN_OPERATIVO_CQ4_2013')
list_of_inputs_for_model3.append('MARGEN_OPERATIVO_CQ4_2013')
list_of_inputs_for_model4.append('MARGEN_OPERATIVO_CQ4_2013')

list_of_inputs_for_model0.append('MARGEN_OPERATIVO_CQ4_2014')
list_of_inputs_for_model1.append('MARGEN_OPERATIVO_CQ4_2014')
list_of_inputs_for_model2.append('MARGEN_OPERATIVO_CQ4_2014')
list_of_inputs_for_model3.append('MARGEN_OPERATIVO_CQ4_2014')
list_of_inputs_for_model4.append('MARGEN_OPERATIVO_CQ4_2014')

list_of_inputs_for_model1.append('MARGEN_OPERATIVO_CQ1_2015')
list_of_inputs_for_model2.append('MARGEN_OPERATIVO_CQ1_2015')
list_of_inputs_for_model3.append('MARGEN_OPERATIVO_CQ1_2015')
list_of_inputs_for_model4.append('MARGEN_OPERATIVO_CQ1_2015')

list_of_inputs_for_model2.append('MARGEN_OPERATIVO_CQ2_2015')
list_of_inputs_for_model3.append('MARGEN_OPERATIVO_CQ2_2015')
list_of_inputs_for_model4.append('MARGEN_OPERATIVO_CQ2_2015')

list_of_inputs_for_model3.append('MARGEN_OPERATIVO_CQ3_2015')
list_of_inputs_for_model4.append('MARGEN_OPERATIVO_CQ3_2015')

list_of_inputs_for_model4.append('MARGEN_OPERATIVO_CQ4_2015')

# PRODUCTIVIDAD PERSONAL
list_of_inputs_for_model0.append('PRODUCTIVIDAD_PERSONAL_CQ4_2013')
list_of_inputs_for_model1.append('PRODUCTIVIDAD_PERSONAL_CQ4_2013')
list_of_inputs_for_model2.append('PRODUCTIVIDAD_PERSONAL_CQ4_2013')
list_of_inputs_for_model3.append('PRODUCTIVIDAD_PERSONAL_CQ4_2013')
list_of_inputs_for_model4.append('PRODUCTIVIDAD_PERSONAL_CQ4_2013')

list_of_inputs_for_model0.append('PRODUCTIVIDAD_PERSONAL_CQ4_2014')
list_of_inputs_for_model1.append('PRODUCTIVIDAD_PERSONAL_CQ4_2014')
list_of_inputs_for_model2.append('PRODUCTIVIDAD_PERSONAL_CQ4_2014')
list_of_inputs_for_model3.append('PRODUCTIVIDAD_PERSONAL_CQ4_2014')
list_of_inputs_for_model4.append('PRODUCTIVIDAD_PERSONAL_CQ4_2014')

list_of_inputs_for_model1.append('PRODUCTIVIDAD_PERSONAL_CQ1_2015')
list_of_inputs_for_model2.append('PRODUCTIVIDAD_PERSONAL_CQ1_2015')
list_of_inputs_for_model3.append('PRODUCTIVIDAD_PERSONAL_CQ1_2015')
list_of_inputs_for_model4.append('PRODUCTIVIDAD_PERSONAL_CQ1_2015')

list_of_inputs_for_model2.append('PRODUCTIVIDAD_PERSONAL_CQ2_2015')
list_of_inputs_for_model3.append('PRODUCTIVIDAD_PERSONAL_CQ2_2015')
list_of_inputs_for_model4.append('PRODUCTIVIDAD_PERSONAL_CQ2_2015')

list_of_inputs_for_model3.append('PRODUCTIVIDAD_PERSONAL_CQ3_2015')
list_of_inputs_for_model4.append('PRODUCTIVIDAD_PERSONAL_CQ3_2015')

list_of_inputs_for_model4.append('PRODUCTIVIDAD_PERSONAL_CQ4_2015')

# %% [markdown]
# #### Selección de variables

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

print "STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 0..."

X0 = df[list_of_inputs_for_model0]
y0 = df[target_variable]

mi0 = mutual_info_regression(X0, y0, discrete_features=0)

df_mi0 = pd.DataFrame(
    {'Variable': list_of_inputs_for_model0,
     'MI': mi0
    })

# Filtramos por aquellas variables que tienen un Mutual Information > 0.1
df_var0 = df_mi0[(df_mi0>=0.1)].dropna(axis=0)
in_model0 = df_var0['Variable'].tolist()
in_model0
# Out:
# STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 0...
# [u'IS_DEPRECIATION_AND_AMORTIZATION_FY_2014',
#  u'NET_INCOME_CQ4_2014',
#  u'BEST_TARGET_PRICE_FY_2013',
#  u'BEST_TARGET_PRICE_FY_2014',
#  u'BEST_TARGET_PRICE_CQ4_2013',
#  u'BEST_TARGET_PRICE_CQ1_2014',
#  u'BEST_TARGET_PRICE_CQ4_2014',
#  u'BEST_TARGET_HI_FY_2014',
#  u'BEST_TARGET_HI_CQ1_2014',
#  u'BEST_TARGET_HI_CQ3_2014',
#  u'BEST_TARGET_HI_CQ4_2014',
#  u'BEST_TARGET_LO_FY_2013',
#  u'BEST_TARGET_LO_FY_2014',
#  u'BEST_TARGET_LO_CQ1_2014',
#  u'BEST_TARGET_LO_CQ4_2014',
#  u'BEST_TARGET_MEDIAN_FY_2013',
#  u'BEST_TARGET_MEDIAN_FY_2014',
#  u'BEST_TARGET_MEDIAN_CQ4_2013',
#  u'BEST_TARGET_MEDIAN_CQ1_2014',
#  u'BEST_TARGET_MEDIAN_CQ4_2014',
#  u'CUR_MKT_CAP_CQ4_2014',
#  u'BB_1YR_DEFAULT_PROB_CQ4_2013',
#  u'BB_1YR_DEFAULT_PROB_CQ1_2014',
#  u'BB_1YR_DEFAULT_PROB_CQ2_2014',
#  u'BB_1YR_DEFAULT_PROB_CQ3_2014',
#  u'BB_1YR_DEFAULT_PROB_CQ4_2014',
#  'FONDO_MANIOBRA_CQ4_2014',
#  'DEUDA_CUR_CQ4_2013',
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

print "STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 1..."

X1 = df[list_of_inputs_for_model1]
y1 = df[target_variable]

mi1 = mutual_info_regression(X1, y1, discrete_features=0)

df_mi1 = pd.DataFrame(
    {'Variable': list_of_inputs_for_model1,
     'MI': mi1
    })

# Filtramos por aquellas variables que tienen un Mutual Information > 0.1
df_var1 = df_mi1[(df_mi1>=0.1)].dropna(axis=0)
in_model1 = df_var1['Variable'].tolist()
in_model1
# Out:
# STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 1...
# [u'IS_DEPRECIATION_AND_AMORTIZATION_FY_2014',
#  u'NET_INCOME_CQ4_2014',
#  u'NET_INCOME_CQ1_2015',
#  u'BEST_TARGET_PRICE_FY_2013',
#  u'BEST_TARGET_PRICE_FY_2014',
#  u'BEST_TARGET_PRICE_CQ4_2013',
#  u'BEST_TARGET_PRICE_CQ4_2014',
#  u'BEST_TARGET_HI_FY_2013',
#  u'BEST_TARGET_HI_FY_2014',
#  u'BEST_TARGET_HI_CQ1_2014',
#  u'BEST_TARGET_HI_CQ4_2014',
#  u'BEST_TARGET_LO_FY_2013',
#  u'BEST_TARGET_LO_FY_2014',
#  u'BEST_TARGET_LO_CQ1_2014',
#  u'BEST_TARGET_LO_CQ4_2014',
#  u'BEST_TARGET_LO_CQ1_2015',
#  u'BEST_TARGET_MEDIAN_FY_2013',
#  u'BEST_TARGET_MEDIAN_FY_2014',
#  u'BEST_TARGET_MEDIAN_CQ4_2013',
#  u'BEST_TARGET_MEDIAN_CQ1_2014',
#  u'BEST_TARGET_MEDIAN_CQ3_2014',
#  u'BEST_TARGET_MEDIAN_CQ4_2014',
#  u'CUR_MKT_CAP_CQ4_2014',
#  u'CUR_MKT_CAP_CQ1_2015',
#  u'BB_1YR_DEFAULT_PROB_CQ4_2013',
#  u'BB_1YR_DEFAULT_PROB_CQ1_2014',
#  u'BB_1YR_DEFAULT_PROB_CQ2_2014',
#  u'BB_1YR_DEFAULT_PROB_CQ3_2014',
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

print "STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 2..."

X2 = df[list_of_inputs_for_model2]
y2 = df[target_variable]

mi2 = mutual_info_regression(X2, y2, discrete_features=0)

df_mi2 = pd.DataFrame(
    {'Variable': list_of_inputs_for_model2,
     'MI': mi2
    })

# Filtramos por aquellas variables que tienen un Mutual Information > 0.1
df_var2 = df_mi2[(df_mi2>=0.1)].dropna(axis=0)
in_model2 = df_var2['Variable'].tolist()
in_model2
# Out:
# STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 2...
# [u'IS_DEPRECIATION_AND_AMORTIZATION_FY_2014',
#  u'IS_OPER_INC_CQ2_2015',
#  u'PRETAX_INC_CQ2_2015',
#  u'IS_INC_TAX_EXP_CQ2_2015',
#  u'NET_INCOME_CQ4_2014',
#  u'BEST_TARGET_PRICE_FY_2013',
#  u'BEST_TARGET_PRICE_FY_2014',
#  u'BEST_TARGET_PRICE_CQ4_2013',
#  u'BEST_TARGET_PRICE_CQ1_2014',
#  u'BEST_TARGET_PRICE_CQ4_2014',
#  u'BEST_TARGET_PRICE_CQ2_2015',
#  u'BEST_TARGET_HI_FY_2014',
#  u'BEST_TARGET_HI_CQ4_2014',
#  u'BEST_TARGET_HI_CQ2_2015',
#  u'BEST_TARGET_LO_FY_2014',
#  u'BEST_TARGET_LO_CQ4_2013',
#  u'BEST_TARGET_LO_CQ1_2014',
#  u'BEST_TARGET_LO_CQ4_2014',
#  u'BEST_TARGET_LO_CQ1_2015',
#  u'BEST_TARGET_LO_CQ2_2015',
#  u'BEST_TARGET_MEDIAN_FY_2013',
#  u'BEST_TARGET_MEDIAN_FY_2014',
#  u'BEST_TARGET_MEDIAN_CQ4_2013',
#  u'BEST_TARGET_MEDIAN_CQ1_2014',
#  u'BEST_TARGET_MEDIAN_CQ4_2014',
#  u'BEST_TARGET_MEDIAN_CQ2_2015',
#  u'CUR_MKT_CAP_CQ4_2014',
#  u'CUR_MKT_CAP_CQ1_2015',
#  u'CUR_MKT_CAP_CQ2_2015',
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

print "STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 3..."

X3 = df[list_of_inputs_for_model3]
y3 = df[target_variable]

mi3 = mutual_info_regression(X3, y3, discrete_features=0)

df_mi3 = pd.DataFrame(
    {'Variable': list_of_inputs_for_model3,
     'MI': mi3
    })

# Filtramos por aquellas variables que tienen un Mutual Information > 0.1
df_var3 = df_mi3[(df_mi3>=0.1)].dropna(axis=0)
in_model3 = df_var3['Variable'].tolist()
in_model3
# Out:
# STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 3...
# [u'IS_DEPRECIATION_AND_AMORTIZATION_FY_2014',
#  u'IS_OPER_INC_CQ2_2015',
#  u'PRETAX_INC_CQ2_2015',
#  u'IS_INC_TAX_EXP_CQ2_2015',
#  u'NET_INCOME_CQ4_2014',
#  u'BEST_TARGET_PRICE_FY_2013',
#  u'BEST_TARGET_PRICE_FY_2014',
#  u'BEST_TARGET_PRICE_CQ4_2013',
#  u'BEST_TARGET_PRICE_CQ1_2014',
#  u'BEST_TARGET_PRICE_CQ4_2014',
#  u'BEST_TARGET_PRICE_CQ2_2015',
#  u'BEST_TARGET_PRICE_CQ3_2015',
#  u'BEST_TARGET_HI_FY_2014',
#  u'BEST_TARGET_HI_CQ1_2014',
#  u'BEST_TARGET_HI_CQ4_2014',
#  u'BEST_TARGET_HI_CQ2_2015',
#  u'BEST_TARGET_HI_CQ3_2015',
#  u'BEST_TARGET_LO_FY_2014',
#  u'BEST_TARGET_LO_CQ1_2014',
#  u'BEST_TARGET_LO_CQ4_2014',
#  u'BEST_TARGET_LO_CQ1_2015',
#  u'BEST_TARGET_LO_CQ2_2015',
#  u'BEST_TARGET_LO_CQ3_2015',
#  u'BEST_TARGET_MEDIAN_FY_2013',
#  u'BEST_TARGET_MEDIAN_CQ4_2013',
#  u'BEST_TARGET_MEDIAN_CQ1_2014',
#  u'BEST_TARGET_MEDIAN_CQ2_2015',
#  u'BEST_TARGET_MEDIAN_CQ3_2015',
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

print "STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 4..."

X4 = df[list_of_inputs_for_model4]
y4 = df[target_variable]

mi4 = mutual_info_regression(X4, y4, discrete_features=0)

df_mi4 = pd.DataFrame(
    {'Variable': list_of_inputs_for_model4,
     'MI': mi4
    })

# Filtramos por aquellas variables que tienen un Mutual Information > 0.1
df_var4 = df_mi4[(df_mi4>=0.1)].dropna(axis=0)
in_model4 = df_var4['Variable'].tolist()
in_model4
# Out:
# STEP 2: SELECTING CHARACTERISTICS TO ENTER INTO THE MODEL 4...
# [u'SALES_REV_TURN_FY_2015',
#  u'IS_COST_OF_MATL_FY_2015',
#  u'IS_DEPRECIATION_AND_AMORTIZATION_FY_2014',
#  u'IS_DEPRECIATION_AND_AMORTIZATION_FY_2015',
#  u'IS_OPER_INC_CQ2_2015',
#  u'PRETAX_INC_FY_2015',
#  u'PRETAX_INC_CQ2_2015',
#  u'PRETAX_INC_CQ4_2015',
#  u'IS_INC_TAX_EXP_FY_2015',
#  u'IS_INC_TAX_EXP_CQ2_2015',
#  u'NET_INCOME_CQ4_2014',
#  u'NET_INCOME_CQ1_2015',
#  u'NET_INCOME_CQ4_2015',
#  u'BEST_TARGET_PRICE_FY_2013',
#  u'BEST_TARGET_PRICE_FY_2014',
#  u'BEST_TARGET_PRICE_FY_2015',
#  u'BEST_TARGET_PRICE_CQ4_2013',
#  u'BEST_TARGET_PRICE_CQ1_2014',
#  u'BEST_TARGET_PRICE_CQ4_2014',
#  u'BEST_TARGET_PRICE_CQ2_2015',
#  u'BEST_TARGET_PRICE_CQ3_2015',
#  u'BEST_TARGET_PRICE_CQ4_2015',
#  u'BEST_TARGET_HI_FY_2014',
#  u'BEST_TARGET_HI_FY_2015',
#  u'BEST_TARGET_HI_CQ1_2014',
#  u'BEST_TARGET_HI_CQ4_2014',
#  u'BEST_TARGET_HI_CQ2_2015',
#  u'BEST_TARGET_HI_CQ3_2015',
#  u'BEST_TARGET_HI_CQ4_2015',
# ...

# %% [markdown]
# #### Desarrollo del modelo

# %%
print "STEP 3: DEVELOPING THE MODEL 0..."

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

X = df[in_model0]
y = df[target_variable]

#model = sm.Logit(y,X)

try:
    model0 = RandomForestRegressor(n_estimators=3000)
    #model0 = AdaBoostRegressor(RandomForestRegressor(),n_estimators=3000)
    result0 = model0.fit(X, y)
    #print result.summary()
    y_pred = result0.predict(X)
    #with open("model0.pkl", "wb") as f:
    #    cPickle.dump(model0, f)
except np.linalg.linalg.LinAlgError as err:
    if 'Singular matrix' in err.message:
        print "MODEL-INVALID (Singular Matrix)"
    else:
        raise
# Out:
# STEP 3: DEVELOPING THE MODEL 0...

# %%
print "STEP 3: DEVELOPING THE MODEL 1..."

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

X = df[in_model1]
y = df[target_variable]

#model = sm.Logit(y,X)

try:
    model1 = RandomForestRegressor(n_estimators=3000)
    #model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=3000)
    result1 = model1.fit(X, y)
    #print result.summary()
    y_pred = result1.predict(X)
    with open("model1.pkl", "wb") as f:
        cPickle.dump(model1, f)
except np.linalg.linalg.LinAlgError as err:
    if 'Singular matrix' in err.message:
        print "MODEL-INVALID (Singular Matrix)"
    else:
        raise
# Out:
# STEP 3: DEVELOPING THE MODEL 1...

# %%
print "STEP 3: DEVELOPING THE MODEL 2..."

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

X = df[in_model2]
y = df[target_variable]

#model = sm.Logit(y,X)

try:
    model2 = RandomForestRegressor(n_estimators=3000)
    #model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=3000)
    result2 = model2.fit(X, y)
    #print result.summary()
    y_pred = result2.predict(X)
    with open("model2.pkl", "wb") as f:
        cPickle.dump(model2, f)
except np.linalg.linalg.LinAlgError as err:
    if 'Singular matrix' in err.message:
        print "MODEL-INVALID (Singular Matrix)"
    else:
        raise
# Out:
# STEP 3: DEVELOPING THE MODEL 2...

# %%
print "STEP 3: DEVELOPING THE MODEL 3..."

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

X = df[in_model3]
y = df[target_variable]

#model = sm.Logit(y,X)

try:
    model3 = RandomForestRegressor(n_estimators=3000)
    #model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=3000)
    result3= model3.fit(X, y)
    #print result.summary()
    y_pred = result3.predict(X)
    with open("model3.pkl", "wb") as f:
        cPickle.dump(model3, f)
except np.linalg.linalg.LinAlgError as err:
    if 'Singular matrix' in err.message:
        print "MODEL-INVALID (Singular Matrix)"
    else:
        raise
# Out:
# STEP 3: DEVELOPING THE MODEL 3...

# %%
print "STEP 3: DEVELOPING THE MODEL 4..."

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

X = df[in_model4]
y = df[target_variable]

#model = sm.Logit(y,X)

try:
    model4 = RandomForestRegressor(n_estimators=3000)
    #model = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),n_estimators=3000)
    result4 = model4.fit(X, y)
    #print result.summary()
    y_pred = result4.predict(X)
    with open("model4.pkl", "wb") as f:
        cPickle.dump(model4, f)
except np.linalg.linalg.LinAlgError as err:
    if 'Singular matrix' in err.message:
        print "MODEL-INVALID (Singular Matrix)"
    else:
        raise
# Out:
# STEP 3: DEVELOPING THE MODEL 4...

# %%
print "STEP 4: ASSESSING THE MODEL..."

# CALCULATING GINI PERFORMANCE ON DEVELOPMENT SAMPLE
from scipy.stats import spearmanr
spearman_correlation= spearmanr(y, y_pred)
print "Spearman Rank Correlation = ", spearman_correlation
# Out:
# STEP 4: ASSESSING THE MODEL...
# Spearman Rank Correlation =  SpearmanrResult(correlation=0.80699447807640634, pvalue=7.7213954651914726e-28)
