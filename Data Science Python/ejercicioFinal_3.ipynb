# %% [markdown]
# # Parte 3

# %% [markdown]
# ### Podemos descargar datos de empresas del dataset Forbes2000 (paquete HSAUR) mediante get_rdataset(). Encontraremos un ranking de empresas categorizadas por sector, y con datos de su país, ventas, beneficios, recursos y valor de mercado.

# %%
import re
from statsmodels import datasets
df = datasets.get_rdataset('Forbes2000', package='HSAUR')
df_Forbes2000 = df['data']
df_Forbes2000.head(5)
# Out:
#    rank                 name         country              category   sales  \
# 0     1            Citigroup   United States               Banking   94.71
# 1     2     General Electric   United States         Conglomerates  134.19
# 2     3  American Intl Group   United States             Insurance   76.66
# 3     4           ExxonMobil   United States  Oil & gas operations  222.88
# 4     5                   BP  United Kingdom  Oil & gas operations  232.57
#
#    profits   assets  marketvalue
# 0    17.85  1264.03       255.30
# 1    15.59   626.93       328.54
# 2     6.46   647.66       194.87
# 3    20.96   166.99       277.02
# 4    10.27   177.57       173.54

# %% [markdown]
# #### 1. Seleccionar del dataframe los nombres de empresa que incluyen "elect" (sin tener en cuenta mayúsculas). Intentamos con esto obtener empresas “del sector de la electricidad” de forma aproximada.

# %%
df_electricas = df_Forbes2000[df_Forbes2000.name.str.contains('elect', re.IGNORECASE, regex=True, na=False)]
df_electricas
# Out:
#       rank                     name      country  \
# 424    425       STMicroelectronics  Switzerland
# 829    830  United Microelectronics       Taiwan
# 1820  1821  Chi Mei Optoelectronics       Taiwan
#
#                              category  sales  profits  assets  marketvalue
# 424                    Semiconductors   7.98     0.28   11.98        24.11
# 829                    Semiconductors   2.18     0.20    9.29        14.66
# 1820  Technology hardware & equipment   1.72     0.13    2.62         3.68

# %% [markdown]
# #### 2. Utilizando como índice el país y la categoría y ordenándolo (sort_index), encontrar el valor de mercado de las empresas japonesas y estadounidenses.

# %%
#Ordenar datos
df_Forbes2000_sort = df_Forbes2000.set_index(['country', 'category'])
df_Forbes2000_sort.sort_index(inplace=True)
df_Forbes2000_sort
# Out:
#                                             rank                        name  \
# country       category
# Africa        Food markets                  1864  Metro Cash and Carry South
#               Insurance                      950                Sanlam South
# Australia     Banking                         86         Natl Australia Bank
#               Banking                        126     Commonwealth Bank Group
#               Banking                        149       Westpac Banking Group
#               Banking                        160                 ANZ Banking
#               Banking                        517              St George Bank
#               Conglomerates                  733                  Wesfarmers
#               Construction                  1058                Rinker Group
#               Construction                  1157                   CSR Group
#               Construction                  1549                       Boral
# ...

# %%
df_countries = df_Forbes2000_sort.loc[['Japan', 'United States'], ['name','marketvalue']]
print df_countries.tail(5)
print df_countries.head(5)
# Out:
#                                         name  marketvalue
# country       category
# United States Utilities                  DPL         2.54
#               Utilities    Hawaiian Electric         1.94
#               Utilities   Sierra Pacific Res         0.92
#               Utilities  Equitable Resources         2.73
#               Utilities               Aquila         0.82
#                                        name  marketvalue
# country category
# Japan   Banking   Sumitomo Mitsui Financial        31.87
#         Banking       Mitsubishi Tokyo Finl        49.92
#         Banking            Mizuho Financial        30.87
#         Banking                UFJ Holdings        23.71
#         Banking             Resona Holdings        13.41

# %% [markdown]
# #### 3. Sobre el mismo subconjunto de empresas eléctricas, obtener el país donde el sector de utilities tiene mayor valor de mercado medio en sus empresas.

# %% [markdown]
# #### 4. Volviendo al dataset original, obtener las empresas españolas.

# %%
df_spain = df_Forbes2000[(df_Forbes2000.country=='Spain')]
df_spain
# Out:
#       rank                       name country                       category  \
# 38      39    Banco Santander Central   Spain                        Banking
# 56      57  BBVA-Banco Bilbao Vizcaya   Spain                        Banking
# 108    109                 Repsol-YPF   Spain           Oil & gas operations
# 114    115               Endesa Group   Spain                      Utilities
# 188    189                  Iberdrola   Spain                      Utilities
# 378    379      Banco Popular Espaqol   Spain                        Banking
# 408    409                 Telefsnica   Spain    Telecommunications services
# 462    463            Gas Natural SDG   Spain                      Utilities
# 472    473                    Altadis   Spain           Food drink & tobacco
# 529    530               Unisn Fenosa   Spain                      Utilities
# 532    533                      Cepsa   Spain           Oil & gas operations
# ...

# %% [markdown]
# #### 5. Indexar el dataframe anterior por beneficios (profits) y obtener los nombres y rangos de las que tengan un beneficio nulo o negativo. Nota: intenta indexar de manera mixta con números (filas) y etiquetas columnas), hay una operación específica para esto en pandas.

# %%
df_spain.set_index('profits', inplace=True)
df_spain.sort_index(inplace=True)
df_spain.ix[:0,:]
# Out:
# /media/japegon/Datos/ProgramData/Anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#          rank        name country                     category  sales  assets  \
# profits
# -5.86     409  Telefsnica   Spain  Telecommunications services  29.84   60.65
# -0.06    1993   Sogecable   Spain                        Media   1.03    1.53
#
#          marketvalue
# profits
# -5.86          86.39
# -0.06           6.02
